# %%
import sys
sys.path.append("../")
from pyproj import CRS
import numpy as np
import sys
from osgeo import gdal
import xarray as xr
import matplotlib.pyplot as plt
from matplotlib import colors
import matplotlib.dates as mdates
import matplotlib as mpl
from matplotlib.ticker import FuncFormatter
from datetime import datetime
from time import time
from collections import Counter
import pandas as pd #for data analysing
import openpyxl
import os

# %%
##### pour savoir ou je suis dans mon environnement
os.getcwd()
# Out:
# '/home/charlottepoussin/variable'

# %%
###j'ouvre dataset
NDSI_SON = xr.open_dataset('NDSI_JJA_afterSL_b_nc.nc')

# %%
NDSI_SON.z.values
# Out:
# array(['1985-06-01T00:00:00.000000000', '1985-07-01T00:00:00.000000000',
#        '1985-08-01T00:00:00.000000000', '1986-06-01T00:00:00.000000000',
#        '1986-07-01T00:00:00.000000000', '1986-08-01T00:00:00.000000000',
#        '1987-06-01T00:00:00.000000000', '1987-07-01T00:00:00.000000000',
#        '1987-08-01T00:00:00.000000000', '1988-06-01T00:00:00.000000000',
#        '1988-07-01T00:00:00.000000000', '1988-08-01T00:00:00.000000000',
#        '1989-06-01T00:00:00.000000000', '1989-07-01T00:00:00.000000000',
#        '1989-08-01T00:00:00.000000000', '1990-06-01T00:00:00.000000000',
#        '1990-07-01T00:00:00.000000000', '1990-08-01T00:00:00.000000000',
#        '1991-06-01T00:00:00.000000000', '1991-07-01T00:00:00.000000000',
#        '1991-08-01T00:00:00.000000000', '1992-06-01T00:00:00.000000000',
#        '1992-07-01T00:00:00.000000000', '1992-08-01T00:00:00.000000000',
#        '1993-06-01T00:00:00.000000000', '1993-07-01T00:00:00.000000000',
#        '1993-08-01T00:00:00.000000000', '1994-06-01T00:00:00.000000000',
#        '1994-07-01T00:00:00.000000000', '1994-08-01T00:00:00.000000000',
#        '1995-06-01T00:00:00.000000000', '1995-07-01T00:00:00.000000000',
#        '1995-08-01T00:00:00.000000000', '1996-06-01T00:00:00.000000000',
#        '1996-07-01T00:00:00.000000000', '1996-08-01T00:00:00.000000000',
#        '1997-06-01T00:00:00.000000000', '1997-07-01T00:00:00.000000000',
#        '1997-08-01T00:00:00.000000000', '1998-06-01T00:00:00.000000000',
#        '1998-07-01T00:00:00.000000000', '1998-08-01T00:00:00.000000000',
#        '1999-06-01T00:00:00.000000000', '1999-07-01T00:00:00.000000000',
#        '1999-08-01T00:00:00.000000000', '2000-06-01T00:00:00.000000000',
#        '2000-07-01T00:00:00.000000000', '2000-08-01T00:00:00.000000000',
#        '2001-06-01T00:00:00.000000000', '2001-07-01T00:00:00.000000000',
#        '2001-08-01T00:00:00.000000000', '2002-06-01T00:00:00.000000000',
#        '2002-07-01T00:00:00.000000000', '2002-08-01T00:00:00.000000000',
#        '2003-06-01T00:00:00.000000000', '2003-07-01T00:00:00.000000000',
#        '2003-08-01T00:00:00.000000000', '2004-06-01T00:00:00.000000000',
#        '2004-07-01T00:00:00.000000000', '2004-08-01T00:00:00.000000000',
#        '2005-06-01T00:00:00.000000000', '2005-07-01T00:00:00.000000000',
#        '2005-08-01T00:00:00.000000000', '2006-06-01T00:00:00.000000000',
#        '2006-07-01T00:00:00.000000000', '2006-08-01T00:00:00.000000000',
#        '2007-06-01T00:00:00.000000000', '2007-07-01T00:00:00.000000000',
#        '2007-08-01T00:00:00.000000000', '2008-06-01T00:00:00.000000000',
#        '2008-07-01T00:00:00.000000000', '2008-08-01T00:00:00.000000000',
#        '2009-06-01T00:00:00.000000000', '2009-07-01T00:00:00.000000000',
#        '2009-08-01T00:00:00.000000000', '2010-06-01T00:00:00.000000000',
#        '2010-07-01T00:00:00.000000000', '2010-08-01T00:00:00.000000000',
#        '2011-06-01T00:00:00.000000000', '2011-07-01T00:00:00.000000000',
#        '2011-08-01T00:00:00.000000000', '2013-06-01T00:00:00.000000000',
#        '2013-07-01T00:00:00.000000000', '2013-08-01T00:00:00.000000000',
#        '2014-06-01T00:00:00.000000000', '2014-07-01T00:00:00.000000000',
#        '2014-08-01T00:00:00.000000000', '2015-06-01T00:00:00.000000000',
#        '2015-07-01T00:00:00.000000000', '2015-08-01T00:00:00.000000000',
#        '2016-06-01T00:00:00.000000000', '2016-07-01T00:00:00.000000000',
#        '2016-08-01T00:00:00.000000000', '2017-06-01T00:00:00.000000000',
#        '2017-07-01T00:00:00.000000000', '2017-08-01T00:00:00.000000000',
#        '2018-06-01T00:00:00.000000000', '2018-07-01T00:00:00.000000000',
#        '2018-08-01T00:00:00.000000000', '2019-06-01T00:00:00.000000000',
#        '2019-07-01T00:00:00.000000000', '2019-08-01T00:00:00.000000000',
#        '2020-06-01T00:00:00.000000000', '2020-07-01T00:00:00.000000000',
#        '2020-08-01T00:00:00.000000000', '2021-06-01T00:00:00.000000000',
#        '2021-07-01T00:00:00.000000000', '2021-08-01T00:00:00.000000000'],
#       dtype='datetime64[ns]')

# %%
####j'attribue un CRS à mon dataset
crs = CRS.from_string('EPSG:4326')
NDSI_SON.attrs["crs"] = crs.to_proj4()
# Out:
# /home/charlottepoussin/.conda/envs/myenv/lib/python3.12/site-packages/pyproj/crs/crs.py:1293: UserWarning: You will likely lose important projection information when converting to a PROJ string from another format. See: https://proj.org/faq.html#what-is-the-best-format-for-describing-coordinate-reference-systems
#   proj = self._crs.to_proj4(version=version)

# %%
NDSI_SON.snow_step3[1].plot()

# %%
##le faire avant l'analyse et après l'analyse afin de voir le pourcentage de changement
##Before
def compute_cloudpercent_b(array):
    cloud = np.sum(array == 2)
    #print(cloud)
    tot_pix = np.count_nonzero((~np.isnan(array)))
    percentage_cloud_b = round(((float(cloud) / float(tot_pix)) * 100),2)
    return percentage_cloud_b

# %%
##le faire avant l'analyse et après l'analyse afin de voir le pourcentage de changement
##Before
def compute_snowpercent_b(array):
    snow = np.count_nonzero((array == 1) | (array == 100))
    #print(snow)
    tot_pix = np.count_nonzero((~np.isnan(array)))
    snow_percent_b = round(((float(snow) / float(tot_pix)) * 100),2)
    return snow_percent_b

# %%
##le faire avant l'analyse et après l'analyse afin de voir le pourcentage de changement
##Before
def compute_landpercent_b(array):
    land = np.count_nonzero((array == 0) | (array == 200))
    #print(land)
    tot_pix = np.count_nonzero((~np.isnan(array)))
    land_percent_b = round((float(land) / float(tot_pix)) * 100,2)
    return land_percent_b

# %%
##le faire avant l'analyse et après l'analyse afin de voir le pourcentage de changement
##After
def compute_cloudpercent_a(array_copy):
    cloud = np.sum(array_copy  == 2)
    tot_pix = np.count_nonzero((~np.isnan(array_copy)))
    cloud_percent = round((float(cloud) / float(tot_pix)) * 100, 2)
    return cloud_percent

# %%
##le faire avant l'analyse et après l'analyse afin de voir le pourcentage de changement
##After
def compute_snowpercent_a(array_copy):
    snow = np.count_nonzero((array_copy == 1) | (array_copy == 100))
    tot_pix = np.count_nonzero((~np.isnan(array_copy)))
    snow_percent = round((float(snow) / float(tot_pix)) * 100, 2)
    return snow_percent

# %%
##le faire avant l'analyse et après l'analyse afin de voir le pourcentage de changement
##After
def compute_landpercent_a(array_copy):
    land = np.count_nonzero((array_copy == 0) | (array_copy == 200))
    tot_pix = np.count_nonzero((~np.isnan(array_copy)))
    land_percent = round((float(land) / float(tot_pix)) * 100, 2)
    return land_percent

# %%
def step4_gapfilling_cloud(array,array_copy):
    cloud_b = np.sum(array==2)
    cloud_a = np.sum(array_copy==2)
    cloud_step4 = cloud_b - cloud_a 
    step4_gf_cloud = round((float(cloud_step4)/float(cloud_b))*100,2)
    #step3_gf_cloud = ((cloud_step3)/(cloud_b))*100
    return step4_gf_cloud

# %%
def step4_gapfilling_tot(array,array_copy):
    cloudpercent_b = compute_cloudpercent_b(array)
    cloudpercent_a = compute_cloudpercent_a(array_copy)
    step4_gf_tot = round(((cloudpercent_b)-(cloudpercent_a)),2)
    #step3_gf_tot = ((cloudpercent_b)-(cloudpercent_a))
    return step4_gf_tot

# %%
###pour continuer jusuq'à que c'est possible
####pour faire pour chaque i
def step4_internal(array):
    # Je crée une copie pour pouvoir travailler dessus sans changer l'initial
    snow_step4 = array.copy(deep=True)
    
    while True:
        # Get west, north, east & south elements for [1:-1,1:-1] region of input array
        W = snow_step4.values[1:-1, :-2]
        N = snow_step4.values[:-2, 1:-1]
        E = snow_step4.values[1:-1, 2:]
        S = snow_step4.values[2:, 1:-1]

        # Check if at least four arrays have 1 for that same element in that region for snow
        mask_snow = ((((W == 1)| (W == 100)) & ((N == 1)| (N == 100)) & ((E == 1)| (E == 100)) & ((S == 1)| (S == 100))) | (
            ((W == 1)| (W == 100)) & ((N == 1)| (N == 100)) & ((E == 1)| (E == 100))) | (
            ((W == 1)| (W == 100)) & ((N == 1)| (N == 100)) & ((S == 1)| (S == 100))) | (
            ((W == 1)| (W == 100)) & ((E == 1)| (E == 100)) & ((S == 1)| (S == 100))) | (
                ((N == 1)| (N == 100)) & ((E == 1)| (E == 100)) & ((S == 1)| (S == 100)))) & (
                snow_step4.values[1:-1, 1:-1] == 2)

        # Check if at at least four arrays have 0 for that same element in that region for land
        mask_land = ((((W == 0)| (W == 200)) & ((N == 0)| (N == 200)) & ((E == 0)| (E == 200)) & ((S == 0)| (S == 200))) | (
            ((W == 0)| (W == 200)) & ((N == 0)| (N == 200)) & ((E == 0)| (E == 200))) | (
            ((W == 0)| (W == 200)) & ((N == 0)| (N == 200)) & ((S == 0)| (S == 200))) | (
            ((W == 0)| (W == 200)) & ((E == 0)| (E == 200)) & ((S == 0)| (S == 200))) | (
            ((N == 0)| (N == 200)) & ((E == 0)| (E == 200)) & ((S == 0)| (S == 200)))) & (
            snow_step4.values[1:-1, 1:-1] == 2)

        # Use the mask to set corresponding elements
        snow_step4.values[1:-1, 1:-1][mask_snow] = 100
        snow_step4.values[1:-1, 1:-1][mask_land] = 200

        # Check if any modification was made in the current iteration
        if not mask_snow.any() and not mask_land.any():
            break  # Exit the loop if no modifications were made

    return snow_step4

# %% [raw]
# ###pour continuer jusuq'à que c'est possible
# ####pour faire pour chaque i
# def step4_internal(array):
#     # Je crée une copie pour pouvoir travailler dessus sans changer l'initial
#     snow_step4 = array.copy(deep=True)
#
#     while True:
#         # Get west, north, east & south elements for [1:-1,1:-1] region of input array
#         W = snow_step4.values[1:-1, :-2]
#         N = snow_step4.values[:-2, 1:-1]
#         E = snow_step4.values[1:-1, 2:]
#         S = snow_step4.values[2:, 1:-1]
#
#         # Check if at least four arrays have 1 for that same element in that region for snow
#         mask_snow = (((W == 1) & (N == 1) & (
#         E == 1) & (S == 1)) | (
#             (W == 1) & (N == 1) & (
#                 E == 1)) | (
#                     (W == 1) & (N == 1) & (
#                         S == 1)) | (
#                             (W == 1) & (
#                                 E == 1) & (S == 1)) | (
#                                     (N == 1) & (
#                                         E == 1) & (S == 1))) & (
#                                             snow_step4.values[1:-1, 1:-1] == 2)
#
#         # Check if at at least four arrays have 0 for that same element in that region for land
#         mask_land = (((W == 0) & (N == 0) & (
#             E == 0) & (S == 0)) | (
#             (W == 0) & (N == 0) & (
#                 E == 0)) | (
#                     (W == 0) & (N == 0) & (
#                         S == 0)) | (
#                             (W == 0) & (
#                                 E == 0) & (S == 0)) | (
#                                     (N == 0) & (
#                                         E == 0) & (S == 0))) & (
#                                             snow_step4.values[1:-1, 1:-1] == 2)
#
#         # Use the mask to set corresponding elements
#         snow_step4.values[1:-1, 1:-1][mask_snow] = 1
#         snow_step4.values[1:-1, 1:-1][mask_land] = 0
#
#         # Check if any modification was made in the current iteration
#         if not mask_snow.any() and not mask_land.any():
#             break  # Exit the loop if no modifications were made
#
#     return snow_step4

# %%
def step4(array):
    # four-pixels neighboring
    print("Starting step 4")
    ##Calculer le % de nuage avant le processus
    percentage_cloud_b = compute_cloudpercent_b(array)
    print("cloud percent before step 4 : " + str(round(percentage_cloud_b,2)))
    percentage_snow_b = compute_snowpercent_b(array)
    percentage_land_b = compute_landpercent_b(array)
    
    
    # compute 4 pixel snow neighboring
    snow_step4 = step4_internal(array)

    percentage_cloud_a = compute_cloudpercent_a(snow_step4)
    print("cloud percent after step 4 : " + str(round(percentage_cloud_a,2)))
    percentage_snow_a = compute_snowpercent_a(snow_step4)
    percentage_land_a = compute_landpercent_a(snow_step4)

    step4_gf_tot = step4_gapfilling_tot(array,snow_step4)
    print("diminution of cloud tot (%) : " + str(round(step4_gf_tot,2)))
    step4_gf_cloud = step4_gapfilling_cloud(array,snow_step4)
    print("diminution of cloud (%) : " + str(round(step4_gf_cloud,2)))
    

    print("End of step 4")

    return snow_step4

# %%
cloud_percent_b_list = []
snow_percent_b_list = []
land_percent_b_list = []
cloud_percent_a_list = []
snow_percent_a_list = []
land_percent_a_list = []
step4_gapfilling_tot_list = []
step4_gapfilling_cloud_list = []
time_list = []
snow_step4_list = []

# %%
for i in range(len(NDSI_SON.z)):
    print(i)
    snow_step4 = step4(NDSI_SON.snow_step3.isel(z=i))
    snow_step4_list.append(snow_step4)
    cloud_percent_b = compute_cloudpercent_b(NDSI_SON.snow_step3.isel(z=i))
    cloud_percent_b_list.append(cloud_percent_b)
    snow_percent_b = compute_snowpercent_b(NDSI_SON.snow_step3.isel(z=i))
    snow_percent_b_list.append(snow_percent_b)
    land_percent_b = compute_landpercent_b(NDSI_SON.snow_step3.isel(z=i))
    land_percent_b_list.append(land_percent_b)
    time = pd.to_datetime(NDSI_SON.z.isel(z=i).values)
    formatted_date = time.strftime('%Y-%m-%d')
    time_list.append(formatted_date)

    cloud_percent_a = compute_cloudpercent_a(snow_step4)
    cloud_percent_a_list.append(cloud_percent_a)
    snow_percent_a = compute_snowpercent_a(snow_step4)
    snow_percent_a_list.append(snow_percent_a)
    land_percent_a = compute_landpercent_a(snow_step4)
    land_percent_a_list.append(land_percent_a)

    step4_gapfilling_total = step4_gapfilling_tot(NDSI_SON.snow_step3.isel(z=i),snow_step4)
    step4_gapfilling_tot_list.append(step4_gapfilling_total)
    step4_gapfilling_clouds = step4_gapfilling_cloud(NDSI_SON.snow_step3.isel(z=i),snow_step4)
    step4_gapfilling_cloud_list.append(step4_gapfilling_clouds)
# Out:
# 0
# Starting step 4
# cloud percent before step 4 : 42.26
# cloud percent after step 4 : 42.08
# diminution of cloud tot (%) : 0.18
# diminution of cloud (%) : 0.42
# End of step 4
# 1
# Starting step 4
# cloud percent before step 4 : 12.63
# cloud percent after step 4 : 12.47
# diminution of cloud tot (%) : 0.16
# diminution of cloud (%) : 1.28
# End of step 4
# 2
# Starting step 4
# cloud percent before step 4 : 16.85
# cloud percent after step 4 : 16.77
# diminution of cloud tot (%) : 0.08
# diminution of cloud (%) : 0.48
# End of step 4
# 3
# Starting step 4
# cloud percent before step 4 : 20.45
# cloud percent after step 4 : 20.34
# diminution of cloud tot (%) : 0.11
# diminution of cloud (%) : 0.54
# End of step 4
# 4
# Starting step 4
# cloud percent before step 4 : 10.29
# cloud percent after step 4 : 10.25
# diminution of cloud tot (%) : 0.04
# diminution of cloud (%) : 0.4
# End of step 4
# 5
# Starting step 4
# cloud percent before step 4 : 43.49
# cloud percent after step 4 : 43.39
# diminution of cloud tot (%) : 0.1
# diminution of cloud (%) : 0.23
# End of step 4
# 6
# Starting step 4
# cloud percent before step 4 : 58.64
# cloud percent after step 4 : 58.54
# diminution of cloud tot (%) : 0.1
# diminution of cloud (%) : 0.17
# End of step 4
# 7
# Starting step 4
# cloud percent before step 4 : 48.12
# cloud percent after step 4 : 47.94
# diminution of cloud tot (%) : 0.18
# diminution of cloud (%) : 0.38
# End of step 4
# 8
# Starting step 4
# cloud percent before step 4 : 9.98
# cloud percent after step 4 : 9.89
# diminution of cloud tot (%) : 0.09
# diminution of cloud (%) : 0.87
# End of step 4
# 9
# Starting step 4
# cloud percent before step 4 : 19.3
# cloud percent after step 4 : 19.05
# diminution of cloud tot (%) : 0.25
# diminution of cloud (%) : 1.3
# End of step 4
# 10
# Starting step 4
# cloud percent before step 4 : 10.64
# cloud percent after step 4 : 10.56
# diminution of cloud tot (%) : 0.08
# diminution of cloud (%) : 0.75
# End of step 4
# 11
# Starting step 4
# cloud percent before step 4 : 6.32
# cloud percent after step 4 : 6.28
# diminution of cloud tot (%) : 0.04
# diminution of cloud (%) : 0.63
# End of step 4
# 12
# Starting step 4
# cloud percent before step 4 : 45.48
# cloud percent after step 4 : 45.35
# diminution of cloud tot (%) : 0.13
# diminution of cloud (%) : 0.28
# End of step 4
# 13
# Starting step 4
# cloud percent before step 4 : 11.69
# cloud percent after step 4 : 11.65
# diminution of cloud tot (%) : 0.04
# diminution of cloud (%) : 0.37
# End of step 4
# 14
# Starting step 4
# cloud percent before step 4 : 42.6
# cloud percent after step 4 : 42.5
# diminution of cloud tot (%) : 0.1
# diminution of cloud (%) : 0.23
# End of step 4
# 15
# Starting step 4
# cloud percent before step 4 : 60.79
# cloud percent after step 4 : 60.7
# diminution of cloud tot (%) : 0.09
# diminution of cloud (%) : 0.15
# End of step 4
# 16
# Starting step 4
# cloud percent before step 4 : 47.69
# cloud percent after step 4 : 47.56
# diminution of cloud tot (%) : 0.13
# diminution of cloud (%) : 0.26
# End of step 4
# 17
# Starting step 4
# cloud percent before step 4 : 4.02
# cloud percent after step 4 : 3.97
# diminution of cloud tot (%) : 0.05
# diminution of cloud (%) : 1.2
# End of step 4
# 18
# Starting step 4
# cloud percent before step 4 : 20.14
# cloud percent after step 4 : 19.92
# diminution of cloud tot (%) : 0.22
# diminution of cloud (%) : 1.1
# End of step 4
# 19
# Starting step 4
# cloud percent before step 4 : 12.26
# cloud percent after step 4 : 12.14
# diminution of cloud tot (%) : 0.12
# diminution of cloud (%) : 0.94
# End of step 4
# 20
# Starting step 4
# cloud percent before step 4 : 5.81
# cloud percent after step 4 : 5.77
# diminution of cloud tot (%) : 0.04
# diminution of cloud (%) : 0.69
# End of step 4
# 21
# Starting step 4
# cloud percent before step 4 : 11.67
# cloud percent after step 4 : 11.42
# diminution of cloud tot (%) : 0.25
# diminution of cloud (%) : 2.13
# End of step 4
# 22
# Starting step 4
# cloud percent before step 4 : 50.5
# cloud percent after step 4 : 50.36
# diminution of cloud tot (%) : 0.14
# diminution of cloud (%) : 0.27
# End of step 4
# 23
# Starting step 4
# cloud percent before step 4 : 13.09
# cloud percent after step 4 : 13.03
# diminution of cloud tot (%) : 0.06
# diminution of cloud (%) : 0.5
# End of step 4
# 24
# Starting step 4
# cloud percent before step 4 : 15.64
# cloud percent after step 4 : 15.52
# diminution of cloud tot (%) : 0.12
# diminution of cloud (%) : 0.75
# End of step 4
# 25
# Starting step 4
# cloud percent before step 4 : 10.78
# cloud percent after step 4 : 10.74
# diminution of cloud tot (%) : 0.04
# diminution of cloud (%) : 0.41
# End of step 4
# 26
# Starting step 4
# cloud percent before step 4 : 8.78
# cloud percent after step 4 : 8.73
# diminution of cloud tot (%) : 0.05
# diminution of cloud (%) : 0.58
# End of step 4
# 27
# Starting step 4
# cloud percent before step 4 : 46.63
# cloud percent after step 4 : 46.4
# diminution of cloud tot (%) : 0.23
# diminution of cloud (%) : 0.48
# End of step 4
# 28
# Starting step 4
# cloud percent before step 4 : 11.3
# cloud percent after step 4 : 11.22
# diminution of cloud tot (%) : 0.08
# diminution of cloud (%) : 0.71
# End of step 4
# 29
# Starting step 4
# cloud percent before step 4 : 25.57
# cloud percent after step 4 : 25.5
# diminution of cloud tot (%) : 0.07
# diminution of cloud (%) : 0.29
# End of step 4
# 30
# Starting step 4
# cloud percent before step 4 : 20.33
# cloud percent after step 4 : 20.16
# diminution of cloud tot (%) : 0.17
# diminution of cloud (%) : 0.8
# End of step 4
# 31
# Starting step 4
# cloud percent before step 4 : 13.9
# cloud percent after step 4 : 13.84
# diminution of cloud tot (%) : 0.06
# diminution of cloud (%) : 0.44
# End of step 4
# 32
# Starting step 4
# cloud percent before step 4 : 32.12
# cloud percent after step 4 : 31.99
# diminution of cloud tot (%) : 0.13
# diminution of cloud (%) : 0.41
# End of step 4
# 33
# Starting step 4
# cloud percent before step 4 : 11.36
# cloud percent after step 4 : 11.19
# diminution of cloud tot (%) : 0.17
# diminution of cloud (%) : 1.48
# End of step 4
# 34
# Starting step 4
# cloud percent before step 4 : 7.04
# cloud percent after step 4 : 6.99
# diminution of cloud tot (%) : 0.05
# diminution of cloud (%) : 0.78
# End of step 4
# 35
# Starting step 4
# cloud percent before step 4 : 5.94
# cloud percent after step 4 : 5.9
# diminution of cloud tot (%) : 0.04
# diminution of cloud (%) : 0.65
# End of step 4
# 36
# Starting step 4
# cloud percent before step 4 : 55.23
# cloud percent after step 4 : 55.1
# diminution of cloud tot (%) : 0.13
# diminution of cloud (%) : 0.24
# End of step 4
# 37
# Starting step 4
# cloud percent before step 4 : 12.29
# cloud percent after step 4 : 12.24
# diminution of cloud tot (%) : 0.05
# diminution of cloud (%) : 0.39
# End of step 4
# 38
# Starting step 4
# cloud percent before step 4 : 9.02
# cloud percent after step 4 : 8.94
# diminution of cloud tot (%) : 0.08
# diminution of cloud (%) : 0.87
# End of step 4
# 39
# Starting step 4
# cloud percent before step 4 : 13.98
# cloud percent after step 4 : 13.75
# diminution of cloud tot (%) : 0.23
# diminution of cloud (%) : 1.64
# End of step 4
# 40
# Starting step 4
# cloud percent before step 4 : 20.82
# cloud percent after step 4 : 20.75
# diminution of cloud tot (%) : 0.07
# diminution of cloud (%) : 0.36
# End of step 4
# 41
# Starting step 4
# cloud percent before step 4 : 8.32
# cloud percent after step 4 : 8.27
# diminution of cloud tot (%) : 0.05
# diminution of cloud (%) : 0.63
# End of step 4
# 42
# Starting step 4
# cloud percent before step 4 : 17.69
# cloud percent after step 4 : 17.44
# diminution of cloud tot (%) : 0.25
# diminution of cloud (%) : 1.41
# End of step 4
# 43
# Starting step 4
# cloud percent before step 4 : 8.72
# cloud percent after step 4 : 8.53
# diminution of cloud tot (%) : 0.19
# diminution of cloud (%) : 2.13
# End of step 4
# 44
# Starting step 4
# cloud percent before step 4 : 36.02
# cloud percent after step 4 : 35.9
# diminution of cloud tot (%) : 0.12
# diminution of cloud (%) : 0.31
# End of step 4
# 45
# Starting step 4
# cloud percent before step 4 : 11.93
# cloud percent after step 4 : 11.65
# diminution of cloud tot (%) : 0.28
# diminution of cloud (%) : 2.36
# End of step 4
# 46
# Starting step 4
# cloud percent before step 4 : 19.46
# cloud percent after step 4 : 19.34
# diminution of cloud tot (%) : 0.12
# diminution of cloud (%) : 0.61
# End of step 4
# 47
# Starting step 4
# cloud percent before step 4 : 5.7
# cloud percent after step 4 : 5.65
# diminution of cloud tot (%) : 0.05
# diminution of cloud (%) : 0.81
# End of step 4
# 48
# Starting step 4
# cloud percent before step 4 : 10.5
# cloud percent after step 4 : 10.06
# diminution of cloud tot (%) : 0.44
# diminution of cloud (%) : 4.2
# End of step 4
# 49
# Starting step 4
# cloud percent before step 4 : 13.74
# cloud percent after step 4 : 13.66
# diminution of cloud tot (%) : 0.08
# diminution of cloud (%) : 0.55
# End of step 4
# 50
# Starting step 4
# cloud percent before step 4 : 5.42
# cloud percent after step 4 : 5.36
# diminution of cloud tot (%) : 0.06
# diminution of cloud (%) : 1.02
# End of step 4
# 51
# Starting step 4
# cloud percent before step 4 : 15.41
# cloud percent after step 4 : 15.24
# diminution of cloud tot (%) : 0.17
# diminution of cloud (%) : 1.1
# End of step 4
# 52
# Starting step 4
# cloud percent before step 4 : 45.25
# cloud percent after step 4 : 45.16
# diminution of cloud tot (%) : 0.09
# diminution of cloud (%) : 0.2
# End of step 4
# 53
# Starting step 4
# cloud percent before step 4 : 42.45
# cloud percent after step 4 : 42.36
# diminution of cloud tot (%) : 0.09
# diminution of cloud (%) : 0.21
# End of step 4
# 54
# Starting step 4
# cloud percent before step 4 : 63.31
# cloud percent after step 4 : 63.24
# diminution of cloud tot (%) : 0.07
# diminution of cloud (%) : 0.11
# End of step 4
# 55
# Starting step 4
# cloud percent before step 4 : 40.4
# cloud percent after step 4 : 40.3
# diminution of cloud tot (%) : 0.1
# diminution of cloud (%) : 0.26
# End of step 4
# 56
# Starting step 4
# cloud percent before step 4 : 11.96
# cloud percent after step 4 : 11.9
# diminution of cloud tot (%) : 0.06
# diminution of cloud (%) : 0.57
# End of step 4
# 57
# Starting step 4
# cloud percent before step 4 : 54.07
# cloud percent after step 4 : 53.95
# diminution of cloud tot (%) : 0.12
# diminution of cloud (%) : 0.22
# End of step 4
# 58
# Starting step 4
# cloud percent before step 4 : 14.11
# cloud percent after step 4 : 14.04
# diminution of cloud tot (%) : 0.07
# diminution of cloud (%) : 0.47
# End of step 4
# 59
# Starting step 4
# cloud percent before step 4 : 48.4
# cloud percent after step 4 : 48.28
# diminution of cloud tot (%) : 0.12
# diminution of cloud (%) : 0.26
# End of step 4
# 60
# Starting step 4
# cloud percent before step 4 : 12.55
# cloud percent after step 4 : 12.32
# diminution of cloud tot (%) : 0.23
# diminution of cloud (%) : 1.8
# End of step 4
# 61
# Starting step 4
# cloud percent before step 4 : 39.91
# cloud percent after step 4 : 39.81
# diminution of cloud tot (%) : 0.1
# diminution of cloud (%) : 0.26
# End of step 4
# 62
# Starting step 4
# cloud percent before step 4 : 38.51
# cloud percent after step 4 : 38.37
# diminution of cloud tot (%) : 0.14
# diminution of cloud (%) : 0.36
# End of step 4
# 63
# Starting step 4
# cloud percent before step 4 : 15.32
# cloud percent after step 4 : 15.14
# diminution of cloud tot (%) : 0.18
# diminution of cloud (%) : 1.19
# End of step 4
# 64
# Starting step 4
# cloud percent before step 4 : 22.95
# cloud percent after step 4 : 22.87
# diminution of cloud tot (%) : 0.08
# diminution of cloud (%) : 0.33
# End of step 4
# 65
# Starting step 4
# cloud percent before step 4 : 37.79
# cloud percent after step 4 : 37.69
# diminution of cloud tot (%) : 0.1
# diminution of cloud (%) : 0.27
# End of step 4
# 66
# Starting step 4
# cloud percent before step 4 : 39.19
# cloud percent after step 4 : 39.11
# diminution of cloud tot (%) : 0.08
# diminution of cloud (%) : 0.2
# End of step 4
# 67
# Starting step 4
# cloud percent before step 4 : 6.72
# cloud percent after step 4 : 6.68
# diminution of cloud tot (%) : 0.04
# diminution of cloud (%) : 0.54
# End of step 4
# 68
# Starting step 4
# cloud percent before step 4 : 46.19
# cloud percent after step 4 : 46.07
# diminution of cloud tot (%) : 0.12
# diminution of cloud (%) : 0.25
# End of step 4
# 69
# Starting step 4
# cloud percent before step 4 : 56.49
# cloud percent after step 4 : 56.43
# diminution of cloud tot (%) : 0.06
# diminution of cloud (%) : 0.11
# End of step 4
# 70
# Starting step 4
# cloud percent before step 4 : 29.6
# cloud percent after step 4 : 29.52
# diminution of cloud tot (%) : 0.08
# diminution of cloud (%) : 0.27
# End of step 4
# 71
# Starting step 4
# cloud percent before step 4 : 27.25
# cloud percent after step 4 : 27.17
# diminution of cloud tot (%) : 0.08
# diminution of cloud (%) : 0.31
# End of step 4
# 72
# Starting step 4
# cloud percent before step 4 : 40.4
# cloud percent after step 4 : 40.19
# diminution of cloud tot (%) : 0.21
# diminution of cloud (%) : 0.52
# End of step 4
# 73
# Starting step 4
# cloud percent before step 4 : 10.7
# cloud percent after step 4 : 10.64
# diminution of cloud tot (%) : 0.06
# diminution of cloud (%) : 0.56
# End of step 4
# 74
# Starting step 4
# cloud percent before step 4 : 11.21
# cloud percent after step 4 : 11.14
# diminution of cloud tot (%) : 0.07
# diminution of cloud (%) : 0.56
# End of step 4
# 75
# Starting step 4
# cloud percent before step 4 : 19.53
# cloud percent after step 4 : 19.39
# diminution of cloud tot (%) : 0.14
# diminution of cloud (%) : 0.69
# End of step 4
# 76
# Starting step 4
# cloud percent before step 4 : 9.96
# cloud percent after step 4 : 9.91
# diminution of cloud tot (%) : 0.05
# diminution of cloud (%) : 0.51
# End of step 4
# 77
# Starting step 4
# cloud percent before step 4 : 4.04
# cloud percent after step 4 : 4.0
# diminution of cloud tot (%) : 0.04
# diminution of cloud (%) : 1.03
# End of step 4
# 78
# Starting step 4
# cloud percent before step 4 : 57.68
# cloud percent after step 4 : 57.61
# diminution of cloud tot (%) : 0.07
# diminution of cloud (%) : 0.12
# End of step 4
# 79
# Starting step 4
# cloud percent before step 4 : 48.12
# cloud percent after step 4 : 48.0
# diminution of cloud tot (%) : 0.12
# diminution of cloud (%) : 0.25
# End of step 4
# 80
# Starting step 4
# cloud percent before step 4 : 8.8
# cloud percent after step 4 : 8.73
# diminution of cloud tot (%) : 0.07
# diminution of cloud (%) : 0.74
# End of step 4
# 81
# Starting step 4
# cloud percent before step 4 : 44.21
# cloud percent after step 4 : 43.92
# diminution of cloud tot (%) : 0.29
# diminution of cloud (%) : 0.65
# End of step 4
# 82
# Starting step 4
# cloud percent before step 4 : 13.26
# cloud percent after step 4 : 13.15
# diminution of cloud tot (%) : 0.11
# diminution of cloud (%) : 0.86
# End of step 4
# 83
# Starting step 4
# cloud percent before step 4 : 16.85
# cloud percent after step 4 : 16.77
# diminution of cloud tot (%) : 0.08
# diminution of cloud (%) : 0.46
# End of step 4
# 84
# Starting step 4
# cloud percent before step 4 : 17.35
# cloud percent after step 4 : 17.09
# diminution of cloud tot (%) : 0.26
# diminution of cloud (%) : 1.48
# End of step 4
# 85
# Starting step 4
# cloud percent before step 4 : 9.54
# cloud percent after step 4 : 9.41
# diminution of cloud tot (%) : 0.13
# diminution of cloud (%) : 1.39
# End of step 4
# 86
# Starting step 4
# cloud percent before step 4 : 36.4
# cloud percent after step 4 : 36.26
# diminution of cloud tot (%) : 0.14
# diminution of cloud (%) : 0.38
# End of step 4
# 87
# Starting step 4
# cloud percent before step 4 : 15.97
# cloud percent after step 4 : 15.76
# diminution of cloud tot (%) : 0.21
# diminution of cloud (%) : 1.36
# End of step 4
# 88
# Starting step 4
# cloud percent before step 4 : 4.47
# cloud percent after step 4 : 4.38
# diminution of cloud tot (%) : 0.09
# diminution of cloud (%) : 2.08
# End of step 4
# 89
# Starting step 4
# cloud percent before step 4 : 0.87
# cloud percent after step 4 : 0.72
# diminution of cloud tot (%) : 0.15
# diminution of cloud (%) : 17.86
# End of step 4
# 90
# Starting step 4
# cloud percent before step 4 : 7.4
# cloud percent after step 4 : 7.11
# diminution of cloud tot (%) : 0.29
# diminution of cloud (%) : 3.94
# End of step 4
# 91
# Starting step 4
# cloud percent before step 4 : 4.03
# cloud percent after step 4 : 3.76
# diminution of cloud tot (%) : 0.27
# diminution of cloud (%) : 6.72
# End of step 4
# 92
# Starting step 4
# cloud percent before step 4 : 1.72
# cloud percent after step 4 : 1.64
# diminution of cloud tot (%) : 0.08
# diminution of cloud (%) : 4.59
# End of step 4
# 93
# Starting step 4
# cloud percent before step 4 : 1.02
# cloud percent after step 4 : 0.84
# diminution of cloud tot (%) : 0.18
# diminution of cloud (%) : 18.14
# End of step 4
# 94
# Starting step 4
# cloud percent before step 4 : 1.09
# cloud percent after step 4 : 0.97
# diminution of cloud tot (%) : 0.12
# diminution of cloud (%) : 11.36
# End of step 4
# 95
# Starting step 4
# cloud percent before step 4 : 0.67
# cloud percent after step 4 : 0.55
# diminution of cloud tot (%) : 0.12
# diminution of cloud (%) : 18.58
# End of step 4
# 96
# Starting step 4
# cloud percent before step 4 : 4.0
# cloud percent after step 4 : 3.75
# diminution of cloud tot (%) : 0.25
# diminution of cloud (%) : 6.44
# End of step 4
# 97
# Starting step 4
# cloud percent before step 4 : 0.73
# cloud percent after step 4 : 0.61
# diminution of cloud tot (%) : 0.12
# diminution of cloud (%) : 17.56
# End of step 4
# 98
# Starting step 4
# cloud percent before step 4 : 3.4
# cloud percent after step 4 : 3.16
# diminution of cloud tot (%) : 0.24
# diminution of cloud (%) : 7.14
# End of step 4
# 99
# Starting step 4
# cloud percent before step 4 : 0.28
# cloud percent after step 4 : 0.27
# diminution of cloud tot (%) : 0.01
# diminution of cloud (%) : 3.77
# End of step 4
# 100
# Starting step 4
# cloud percent before step 4 : 1.41
# cloud percent after step 4 : 1.23
# diminution of cloud tot (%) : 0.18
# diminution of cloud (%) : 13.04
# End of step 4
# 101
# Starting step 4
# cloud percent before step 4 : 0.75
# cloud percent after step 4 : 0.6
# diminution of cloud tot (%) : 0.15
# diminution of cloud (%) : 19.11
# End of step 4
# 102
# Starting step 4
# cloud percent before step 4 : 3.71
# cloud percent after step 4 : 3.52
# diminution of cloud tot (%) : 0.19
# diminution of cloud (%) : 5.32
# End of step 4
# 103
# Starting step 4
# cloud percent before step 4 : 0.35
# cloud percent after step 4 : 0.31
# diminution of cloud tot (%) : 0.04
# diminution of cloud (%) : 13.24
# End of step 4
# 104
# Starting step 4
# cloud percent before step 4 : 0.94
# cloud percent after step 4 : 0.82
# diminution of cloud tot (%) : 0.12
# diminution of cloud (%) : 13.47
# End of step 4
# 105
# Starting step 4
# cloud percent before step 4 : 6.4
# cloud percent after step 4 : 6.23
# diminution of cloud tot (%) : 0.17
# diminution of cloud (%) : 2.58
# End of step 4
# 106
# Starting step 4
# cloud percent before step 4 : 2.91
# cloud percent after step 4 : 2.63
# diminution of cloud tot (%) : 0.28
# diminution of cloud (%) : 9.44
# End of step 4
# 107
# Starting step 4
# cloud percent before step 4 : 1.12
# cloud percent after step 4 : 0.91
# diminution of cloud tot (%) : 0.21
# diminution of cloud (%) : 19.41
# End of step 4

# %%
snow_step4_concat = xr.concat(snow_step4_list, dim='z')
dataset_step4 = xr.Dataset({'snow_step4': snow_step4_concat})

# %%
data = {
    'Time': time_list,
    'Cloud Percent Before': cloud_percent_b_list,
    'Snow Percent Before': snow_percent_b_list,
    'Land Percent Before': land_percent_b_list,
    'Cloud Percent After': cloud_percent_a_list,
    'Snow Percent After': snow_percent_a_list,
    'Land Percent After': land_percent_a_list,
    'Cloud Reduction (%)': step4_gapfilling_tot_list,
    'Cloud Reduction After (%)': step4_gapfilling_cloud_list,
}

# Créer un DataFrame à partir du dictionnaire
df_step4 = pd.DataFrame(data)
filename = f'df_step6_4nb_JJA_b.xlsx'
filepath = os.path.join('/home/charlottepoussin/Excels', filename)
df_step4.to_excel(filepath, index=False)

# %%
df_step4
# Out:
#            Time  Cloud Percent Before  Snow Percent Before  \
# 0    1985-06-01                 42.26                 4.32
# 1    1985-07-01                 12.63                 4.34
# 2    1985-08-01                 16.85                 1.86
# 3    1986-06-01                 20.45                 3.02
# 4    1986-07-01                 10.29                 1.10
# ..          ...                   ...                  ...
# 103  2020-07-01                  0.35                 2.21
# 104  2020-08-01                  0.94                 2.74
# 105  2021-06-01                  6.40                 9.27
# 106  2021-07-01                  2.91                 2.48
# 107  2021-08-01                  1.12                 1.34
#
#      Land Percent Before  Cloud Percent After  Snow Percent After  \
# 0                  53.42                42.08                4.42
# 1                  83.03                12.47                4.46
# 2                  81.29                16.77                1.89
# 3                  76.53                20.34                3.08
# 4                  88.61                10.25                1.12
# ..                   ...                  ...                 ...
# 103                97.44                 0.31                2.21
# 104                96.31                 0.82                2.74
# 105                84.33                 6.23                9.27
# 106                94.62                 2.63                2.48
# 107                97.54                 0.91                1.34
#
#      Land Percent After  Cloud Reduction (%)  Cloud Reduction After (%)
# 0                 53.50                 0.18                       0.42
# 1                 83.07                 0.16                       1.28
# 2                 81.34                 0.08                       0.48
# 3                 76.57                 0.11                       0.54
# 4                 88.64                 0.04                       0.40
# ..                  ...                  ...                        ...
# 103               97.49                 0.04                      13.24
# 104               96.44                 0.12                      13.47
# 105               84.49                 0.17                       2.58
# 106               94.89                 0.28                       9.44
# 107               97.75                 0.21                      19.41
#
# [108 rows x 9 columns]

# %%
dataset_step4.to_netcdf('NDSI_JJA_step6_4nb_b_nc.nc')
